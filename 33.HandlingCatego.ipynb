# %% [markdown]
# | Algorithm           | Recommended Method        |
# |--------------------|---------------------------|
# | Logistic Regression | Mode / Unknown            |
# | Decision Tree       | Unknown / Mode            |
# | Random Forest       | Unknown                   |
# | XGBoost             | Unknown                   |
# | KNN                 | Mode (before encoding)    |

# %%
import pandas as pd
import numpy as mp
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Downloads\train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.sample(10)
# Out:
#      FireplaceQu GarageQual  SalePrice
# 1             TA         TA     181500
# 1280         NaN         TA     227000
# 316           TA         TA     260000
# 658           Gd         TA      97500
# 720           TA         TA     275000
# 1388          Gd         TA     377500
# 884          NaN         TA     100000
# 1072          TA         TA      91500
# 824           Gd         TA     232600
# 626           TA         TA     139900

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FireplaceQu  770 non-null    object
#  1   GarageQual   1379 non-null   object
#  2   SalePrice    1460 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 34.3+ KB

# %%
df['FireplaceQu'].describe()
# Out:
# count     770
# unique      5
# top        Gd
# freq      380
# Name: FireplaceQu, dtype: object

# %%
df['GarageQual'].describe()
# Out:
# count     1379
# unique       5
# top         TA
# freq      1311
# Name: GarageQual, dtype: object

# %%
df['GarageQual'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: GarageQual
# Non-Null Count  Dtype
# --------------  -----
# 1379 non-null   object
# dtypes: object(1)
# memory usage: 11.5+ KB

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
df['GarageQual'].fillna('TA',inplace=True)

# %%
df['GarageQual'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
x = df['FireplaceQu'].isnull().sum()
y = df['FireplaceQu'].count()
# Out:
# <>:2: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2672\49485671.py:2: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   y = df['FireplaceQu'['Gd']].count()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2672\49485671.py:2: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   y = df['FireplaceQu'['Gd']].count()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 x = df['FireplaceQu'].isnull().sum()
# ----> 2 y = df['FireplaceQu'['Gd']].count()
#
# TypeError: string indices must be integers, not 'str'

# %%
x
# Out:
# np.int64(690)

# %%
y
# Out:
# np.int64(770)

# %%
print(x+y)
# Out:
# 1460

# %%
df.shape
# Out:
# (1460, 3)

# %%
df['FireplaceQu'].fillna('UnKnown',inplace=True)

# %% [markdown]
# __By Sklearn__

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='most_frequent')

# %%
x_train = impute.fit_transform(x_train)
x_test = impute.transform(x_train)

# %%
impute.statistics_
# Out:
# array(['UnKnown', 'TA'], dtype=object)
