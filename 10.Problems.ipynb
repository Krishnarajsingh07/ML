# %% [markdown]
# ## __Business Problem to ML project__
#
#  __eg - > how to increase the revinue of netflix__
#
# - nye coustmer le kr aao
#
# - purane se jyda charge kro
#
# - Jo ja rhe h unko roko
#  Churn rate decrese ( jo chhod kr ja rhe h )  Churn rate of netflix is 4% now days  3.75
#
# __---Type of problems--__
# - Big picture - Identify the person who want to leave the
# 			platform  What i m doing usko rokne k liye or usko ky preshani h
# - ye indentify krna h  Mere imediate plain - > mene usko next month use discount de
# 				 diaaaa Identify ki uski kitni icha h platform chod kr ja rha h .. to hm uskoo unki iccha k according usnko discount denge
#
# __--Current Solution__
# - Koi esi team jisko churn rate ka prediction pta ho age ky hoga to
# unse contact krna pdega
#
# __Getting Data__
#
#
# - Watch Time
#
# - Search but not find
#
# - Content left at the middle
#
# - Clicked on recommendation
#
#
# __Metrics to measure__
# - Apna prediction shi h ya nhi
#
# __Online vs batch__
# - i will prefer online learning  continuos train ho rha h data to ye shi h
#
# __Check assumption__
# - Factor sb jgh kaam krega ya fir kon se desh me
# ky rhega sb ka alg alg krne pdegaaa....
