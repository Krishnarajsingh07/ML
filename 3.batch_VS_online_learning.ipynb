# %% [markdown]
# ## __🔵 1. Batch Learning (Offline Learning)__
#
# Batch Learning means the model is trained using the entire dataset at once.
#
# The system does not update itself automatically. If new data arrives:
#
# You must re-train the model from scratch using old + new data.
#
#
# ⭐ Key Characteristics of Batch Learning
# ✔ 1. Training on full dataset
#
# - All data is loaded into memory or processed in large batches.
#
# ✔ 2. Expensive retraining
#
# - If new data comes:
#
# -Model → outdated
#
# -Must retrain on full dataset (computationally heavy)
#
# ✔ 3. Often more accurate (for static data)
#
# -Since model sees all data together → better stability + accuracy.
#
# ✔ 4. Requires high computing resources
#
# -Large datasets → heavy CPU/GPU + RAM usage.

# %% [markdown]
# __When it is used__
#
#
# ⭐ When to Use Batch Learning
#
# ✔ When data is small to medium size
#
# ✔ When data doesn’t change frequently
#
# ✔ When training time is not an issue
#
# ✔ For offline applications
#
# Examples:
#
# Medical diagnosis
#
# Banking risk models
#
# Image classification datasets (CIFAR, ImageNet)

# %% [markdown]
# __Pros and Corns__
#
# ⭐ Pros of Batch Learning
#
# Higher accuracy
#
# Stable model
#
# Simpler implementation
#
# Works best when data is fixed
#
# ⭐ Cons of Batch Learning
#
# ❌ Cannot adapt to new data quickly
#
# ❌ Requires full retraining
#
# ❌ High memory usage
#
# ❌ Not suitable for real-time systems

# %% [markdown]
# ## __🔵 2. Online Learning (Incremental Learning)__
#
# Online Learning trains the model continuously, feeding data one sample or small batches at a time.
#
# The model updates itself incrementally:
#
# No full retraining
#
# Supports real-time learning
#
#
# __⭐ Key Characteristics of Online Learning__
#
# ✔ 1. Data arrives as streams
#
# Used when data flows continuously (real-time or live feeds).
#
# ✔ 2. Model updates step-by-step
#
# Each new data point updates the model parameters.
#
# ✔ 3. Learns forever
#
# It can learn new patterns and forget older ones.
#
# ✔ 4. Very fast and memory efficient
#
# Uses small batches → low RAM usage.
#
#
#
# ⭐ When to Use Online Learning
#
# ✔ When data is huge or never stops coming
#
# ✔ When real-time decisions are required
#
# ✔ When storing the full dataset is impossible
#
# Examples:
#
# Stock market prediction
#
# Real-time fraud detection
#
# Online advertising
#
# Recommendation systems
#
# Autonomous driving

# %% [markdown]
# ⭐ Pros of Online Learning
#
# Real-time adaptation
#
# Memory efficient
#
# Fast updates
#
# Handles massive datasets
#
# Great for streaming data
#
# ⭐ Cons of Online Learning
#
# ❌ More noise (because training is incremental)
#
# ❌ Sensitive to bad or mislabeled data
#
# ❌ Harder to tune
#
# ❌ Can drift over time if data quality drops
