# %% [markdown]
# # 🔴 Outliers in Machine Learning (ML)
#
# ---
#
# ## 📌 What are Outliers?
# **Outliers** are data points that **significantly differ** from the majority of the data.
# They may occur due to **measurement errors**, **data entry mistakes**, or **rare but valid events**.
#
# ---
#
# ## 📊 Example
# Dataset:
# `[10, 12, 11, 13, 12, 500]`
#
# 👉 **500** is an outlier because it is far from the rest of the values.
#
# ---
#
# ## 🧠 Why Outliers Matter in ML
# Outliers can:
# - Skew **mean and variance**
# - Mislead **distance-based algorithms**
# - Degrade **model accuracy**
# - Cause **overfitting or underfitting**
#
# ---
#
# ## 📉 Algorithms Affected by Outliers
#
# ### ❌ Highly Sensitive
# - Linear Regression
# - Logistic Regression
# - KNN
# - K-Means
# - SVM (with RBF kernel)
#
# ### ✅ Less Sensitive
# - Decision Trees
# - Random Forest
# - Gradient Boosting
#
# ---

# %% [markdown]
# <hr style="border:2px solid red;">

# %% [markdown]
# # ⚠️ When Are Outliers Dangerous in Machine Learning?
#
# ---
#
# ## 📌 Meaning
# Outliers are **dangerous** when they **distort patterns**, **mislead models**, or **cause wrong predictions**.
#
# ---
#
# ## 🚨 Situations When Outliers Are Dangerous
#
# ---
#
# ## 1️⃣ When Using Mean-Based Statistics
# Outliers strongly affect:
# - Mean
# - Variance
# - Standard Deviation
#
# ### Example:
# Data: `[10, 12, 11, 13, 1000]`
#
# - Mean → **209.2** ❌
# - Median → **12** ✅
#
# 📌 Outliers make mean unreliable.
#
# ---
#
# ## 2️⃣ Distance-Based Algorithms
# Algorithms that use distance are **highly sensitive**.
#
# ### Affected Models:
# - KNN
# - K-Means
# - SVM
# - PCA
#
# 📌 Outliers pull centroids and nearest neighbors.
#
# ---
#
# ## 3️⃣ Linear Models
# Outliers:
# - Change regression line
# - Increase error
# - Cause wrong coefficients
#
# ### Affected Models:
# - Linear Regression
# - Logistic Regression
#
# ---
#
# ## 4️⃣ Small Datasets
# - Even **one outlier** can dominate the model
# - Results become unstable
#
# 📌 More dangerous when data size is small.
#
# ---
#
# ## 5️⃣ During Feature Scaling
# Outliers distort:
# - Min-Max Scaling
# - Standardization
#
# 📌 Most values get squeezed into a narrow range.
#
# ---
#
# ## 6️⃣ When They Are Data Errors
# Outliers caused by:
# - Typing mistakes
# - Sensor errors
# - Missing-value placeholders (e.g., -999)
#
# 📌 These should always be fixed or removed.
#
# ---
#
# ## 7️⃣ In Model Evaluation
# Outliers can:
# - Inflate RMSE
# - Mislead accuracy
# - Hide poor model performance
#
# ---
#
# ## 🛑 When Outliers Are NOT Dangerous
# - Fraud detection
# - Anomaly detection
# - Rare-event prediction
# - Tree-based models (Random Forest, XGBoost)
#
# ---
#
# ## 🧠 How to Decide What to Do
# Ask:
# 1. Is it a data error?
# 2. Is it a rare but valid case?
# 3. Does it affect model performance?
#
# ---
#
# ## 📌 Exam-Oriented One-Liner
# > Outliers are dangerous when they distort statistical measures, affect distance-based models, or arise from data errors.
#
# ---
#
# ## ✅ Final Takeaway
# > **Never remove outliers blindly.**
# > Understand their cause and impact before taking action.
#
# ---

# %% [markdown]
# # 🔴 Types of Treating Outliers in Machine Learning
#
# Outlier treatment depends on **why the outlier exists** and **how it affects the model**.
#
# ---
#
# ## 1️⃣ Trimming (Outlier Removal)
#
# ### 📌 Meaning
# Remove outliers **completely** from the dataset.
#
# ### 🛠️ How
# - IQR method
# - Z-score method
#
# ### ✅ Use When
# - Data entry or measurement errors
# - Large datasets
#
# ### ❌ Avoid When
# - Small datasets
# - Fraud / anomaly detection
#
# ---
#
# ## 2️⃣ Capping (Winsorization)
#
# ### 📌 Meaning
# Replace extreme values with **upper or lower limits**.
#
# ### 🛠️ How
# - IQR-based capping
# - Percentile capping (1%, 99%)
#
# ### ✅ Use When
# - Small datasets
# - Outliers are valid but extreme
#
# ---
#
# ## 3️⃣ Transformation
#
# ### 📌 Meaning
# Apply mathematical transformations to reduce the impact of outliers.
#
# ### 🔁 Types
# - Log transformation
# - Square root
# - Box-Cox
# - Yeo-Johnson
#
# ### ✅ Use When
# - Data is skewed
# - Values are positive (log, Box-Cox)
#
# ---
#
# ## 4️⃣ Imputation-Based Treatment
#
# ### 📌 Meaning
# Treat outliers as missing values and replace them.
#
# ### 🛠️ How
# - Mean / Median
# - KNN
# - MICE
#
# ### ✅ Use When
# - Extreme values are unreliable
# - Moderate number of outliers
#
# ---
#
# ## 5️⃣ Binning (Discretization)
#
# ### 📌 Meaning
# Convert continuous values into categories (bins).
#
# ### 🛠️ How
# - Equal-width binning
# - Equal-frequency binning
#
# ### ✅ Use When
# - Noise reduction required
# - Interpretability is important
#
# ---
#
# ## 6️⃣ Robust Scaling
#
# ### 📌 Meaning
# Scale data using **median and IQR** instead of mean and standard deviation.
#
# ### 🛠️ Tool
# - `RobustScaler`
#
# ### ✅ Use When
# - Using distance-based models
# - Outliers exist but should be retained
#
# ---
#
# ## 7️⃣ Using Robust Models
#
# ### 📌 Meaning
# Use algorithms that are naturally resistant to outliers.
#
# ### 🛠️ Examples
# - Decision Tree
# - Random Forest
# - Gradient Boosting
# - XGBoost
#
# ---
#
# ## 8️⃣ Treat Outliers as Anomalies
#
# ### 📌 Meaning
# Keep outliers as **important signals**.
#
# ### 🛠️ Use In
# - Fraud detection
# - Intrusion detection
# - Fault detection
#
# ---
#
# ## 🔁 Summary Table
#
# | Method | Removes Data | Alters Values |
# |------|--------------|---------------|
# | Trimming | ✅ Yes | ❌ No |
# | Capping | ❌ No | ✅ Yes |
# | Transformation | ❌ No | ✅ Yes |
# | Imputation | ❌ No | ✅ Yes |
# | Binning | ❌ No | ✅ Yes |
# | Robust Models | ❌ No | ❌ No |
#
# ---
#
# ## 📌 Exam-Oriented One-Liner
# > Outliers can be treated by trimming, capping, transformation, imputation, discretization, or using robust models.
#
# ---
#
# ## ✅ Final Takeaway
# > **Choose outlier treatment based on data size, cause of outliers, and model sensitivity.**

# %% [markdown]
# # 📊 Combined Outlier Detection Formulas
# ## Normal & Skewed Distributions
#
# ---
#
# ## 🔹 1. For Normal Distribution (Z-Score Method)
#
# ### 📌 When to Use
# - Data is **approximately symmetric**
# - Mean ≈ Median ≈ Mode
#
# ---
#
# ### 📐 Z-Score Formula
# $$
# Z = \frac{x - \mu}{\sigma}
# $$
#
# Where:
# - $$ x = \text{data point} $$
# - $$ \mu = \text{mean} $$
# - $$ \sigma = \text{standard deviation} $$
#
# ---
#
# ### 🚨 Outlier Condition
# $$
# |Z| > 3 \Rightarrow \text{Outlier}
# $$
#
# ---
#
# ## 🔹 2. For Skewed Distribution (IQR Method)
#
# ### 📌 When to Use
# - Data is **asymmetric**
# - Long left or right tail
# - Mean ≠ Median
#
# ---
#
# ### 📐 IQR Formula
# $$
# IQR = Q3 - Q1
# $$
#
# Where:
# - $$ Q1 = \text{25th percentile} $$
# - $$ Q3 = \text{75th percentile} $$
#
# ---
#
# ### 🚨 Outlier Condition
# $$
# x < Q1 - 1.5 \times IQR
# $$
# or
# $$
# x > Q3 + 1.5 \times IQR
# $$
#
# ---
#
# ## 🔁 Combined Summary (Exam-Ready)
#
# | Distribution Type | Formula Used | Outlier Rule |
# |------------------|-------------|--------------|
# | Normal | $$ Z = \frac{x-\mu}{\sigma} $$ | $$ |Z| > 3 $$ |
# | Skewed | $$ IQR = Q3 - Q1 $$ | $$ x < Q1 - 1.5IQR \ \text{or} \ x > Q3 + 1.5IQR $$ |
#
#
# ---
#
# ## 📌 Exam-Oriented One-Liner
# > For normally distributed data, outliers are detected using the Z-score method, while for skewed data, the IQR method is preferred.
#
# ---
#
# ## ✅ Key Rule to Remember
# > **Check the distribution first → then choose the formula.**

# %% [markdown]
# # ✂️ Winsorization (Capping Outliers)
#
# ---
#
# ## 📌 What is Winsorization?
# **Winsorization** is an outlier treatment technique where **extreme values are replaced (capped)** with specified boundary values instead of being removed.
#
# 👉 It reduces the influence of outliers **without changing dataset size**.
#
# ---
#
# ## 🔍 How It Works
# - Values **below a lower limit** → replaced by the lower limit
# - Values **above an upper limit** → replaced by the upper limit
#
# ---

# %% [markdown]
# # 📊 Percentile
#
# ---
#
# ## 📌 What is a Percentile?
# A **percentile** indicates the value **below which a certain percentage of observations fall**.
#
# 👉 The *k-th percentile* is the value such that **k% of the data is less than or equal to it**.
#
# ---
#
# ## 🔢 Common Percentiles
#
# - $$ P_{25} = Q1 = \text{25th percentile} $$
# - $$ P_{50} = Q2 = \text{50th percentile (Median)} $$
# - $$ P_{75} = Q3 = \text{75th percentile} $$
#
# ---
#
# ## 📐 Percentile Formula (Position-Based)
#
# For a sorted dataset of size \(n\):
#
# $$
# \text{Position of } P_k = \frac{k}{100} \times (n + 1)
# $$
#
# Where:
# - $$ k = \text{percentile (e.g., 25, 50, 75)} $$
# - $$ n = \text{number of observations} $$
#
# ---
