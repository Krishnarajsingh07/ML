# %% [markdown]
# Aspect  	        Artificial Intelligence (AI)	            Machine Learning (ML)	                        Deep Learning (DL)
# Definition	         Machines simulating human intelligence	    Subset of AI - Machines learn from data	        Subset of ML - Uses neural networks
# Goal	            Create intelligent systems	                Learn patterns from data	                    Automatically learn features from raw data
# Scope	            Broadest field	                            Narrower than AI	                            Narrowest (specialized ML)
# Data Needed	        Varies (rules, data, logic)	                Moderate to large datasets	                    Very large datasets
# Human Intervention	High (rule-based) to Low	                Medium (feature engineering needed)	            Low (automatic feature extraction)
# Examples	        Siri, Alexa, Self-driving cars	            Spam filters, Recommendation systems	        Face recognition, ChatGPT, Image generation

# %% [markdown]
# ┌─────────────────────┐
# │   ARTIFICIAL        │ ← Broadest
# │   INTELLIGENCE      │
# │   ┌───────────────┐ │
# │   │   MACHINE     │ │ ← Subset of AI
# │   │   LEARNING    │ │
# │   │   ┌─────────┐ │ │
# │   │   │  DEEP   │ │ │ ← Subset of ML
# │   │   │LEARNING │ │ │
# │   │   └─────────┘ │ │
# │   └───────────────┘ │
# └─────────────────────┘

# %%
# old AI

def medical_diagnous(symptom):
    if 'fever' in symptom or 'bukhar' in symptom:
        print('died')
    elif 'chest pain' in symptom:
        print('time h ')
    else:
        print('kuch nahi hai')

medical_diagnous('fever')
medical_diagnous('bukhar')
# Out:
# died
# died

# %% [markdown]
# Application	                               AI	                           ML                 DL
# Voice Assistant	                Yes(understands commands)	Yes (speech recognition)	    Yes (voice synthesis)
# Netflix Recommendations     	No	                        Yes (collaborative filtering)	No
# Self-driving Cars	            Yes (decision making)	    Yes (object detection)	        Yes (image processing)
# Email Spam Filter	            No	                        Yes (classification)	        No
# ChatGPT	                        Yes	                        Yes	                            Yes (uses transformers)
# Face Unlock	                    Yes	                        Yes                            	Yes (CNN networks)
