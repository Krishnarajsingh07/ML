# %% [markdown]
# - __<span style="color:pink; font-weight:bold;">
# Bias
# </span>__
# <span style="color:red; font-weight:bold;">
# If a machine learning model is not capable of finding the pattern even in the training data, it is called high bias.
# </span>

# %% [markdown]
# - __Variance__
#
# Variance is the error caused by a machine learning model being too complex and highly sensitive to the training data, leading to overfitting and poor generalization.
#
# is variance is the differene between error in train data and test data

# %% [markdown]
# ![NOTE](Screen_shot/Screenshot%202026-01-16%20082734.png)
